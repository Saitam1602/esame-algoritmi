# %%
import pandas as pd

from data.make_dataset import load_data
df = load_data("../data/raw/train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street            Alley  \
# 0   1          60       RL         65.0     8450   Pave  No alley access
# 1   2          20       RL         80.0     9600   Pave  No alley access
# 2   3          60       RL         68.0    11250   Pave  No alley access
# 3   4          70       RL         60.0     9550   Pave  No alley access
# 4   5          60       RL         84.0    14260   Pave  No alley access
#
#   LotShape LandContour Utilities  ... PoolArea   PoolQC     Fence MiscFeature  \
# 0      Reg         Lvl    AllPub  ...        0  No pool  No fence        none
# 1      Reg         Lvl    AllPub  ...        0  No pool  No fence        none
# 2      IR1         Lvl    AllPub  ...        0  No pool  No fence        none
# 3      IR1         Lvl    AllPub  ...        0  No pool  No fence        none
# 4      IR1         Lvl    AllPub  ...        0  No pool  No fence        none
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2   2008        WD         Normal     208500
# 1       0      5   2007        WD         Normal     181500
# 2       0      9   2008        WD         Normal     223500
# 3       0      2   2006        WD        Abnorml     140000
# 4       0     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
from features.build_features import encode_categorical_data, get_best_correlation_columns

df = encode_categorical_data(df)
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60       3.0         65.0     8450     1.0    1.0
# 1        2          20       3.0         80.0     9600     1.0    1.0
# 2        3          60       3.0         68.0    11250     1.0    1.0
# 3        4          70       3.0         60.0     9550     1.0    1.0
# 4        5          60       3.0         84.0    14260     1.0    1.0
# ...    ...         ...       ...          ...      ...     ...    ...
# 1455  1456          60       3.0         62.0     7917     1.0    1.0
# 1456  1457          20       3.0         85.0    13175     1.0    1.0
# 1457  1458          70       3.0         66.0     9042     1.0    1.0
# 1458  1459          20       3.0         68.0     9717     1.0    1.0
# 1459  1460          20       3.0         75.0     9937     1.0    1.0
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# 0          3.0          3.0        0.0  ...         0     3.0    4.0
# 1          3.0          3.0        0.0  ...         0     3.0    4.0
# 2          0.0          3.0        0.0  ...         0     3.0    4.0
# 3          0.0          3.0        0.0  ...         0     3.0    4.0
# 4          0.0          3.0        0.0  ...         0     3.0    4.0
# ...        ...          ...        ...  ...       ...     ...    ...
# 1455       3.0          3.0        0.0  ...         0     3.0    4.0
# 1456       3.0          3.0        0.0  ...         0     3.0    2.0
# 1457       3.0          3.0        0.0  ...         0     3.0    0.0
# 1458       3.0          3.0        0.0  ...         0     3.0    4.0
# 1459       3.0          3.0        0.0  ...         0     3.0    4.0
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0             4.0        0       2    2008       8.0            4.0     208500
# 1             4.0        0       5    2007       8.0            4.0     181500
# 2             4.0        0       9    2008       8.0            4.0     223500
# 3             4.0        0       2    2006       8.0            0.0     140000
# 4             4.0        0      12    2008       8.0            4.0     250000
# ...           ...      ...     ...     ...       ...            ...        ...
# 1455          4.0        0       8    2007       8.0            4.0     175000
# 1456          4.0        0       2    2010       8.0            4.0     210000
# 1457          2.0     2500       5    2010       8.0            4.0     266500
# 1458          4.0        0       4    2010       8.0            4.0     142125
# 1459          4.0        0       6    2008       8.0            4.0     147500
#
# [1460 rows x 81 columns]

# %%
best_correlation_column = get_best_correlation_columns(df, 'SalePrice', .5)
best_correlation_column
# Out:
# Index(['OverallQual', 'GrLivArea', 'GarageCars', 'ExterQual', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'BsmtQual', 'KitchenQual', 'FullBath',
#        'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd'],
#       dtype='object')

# %%
from features.build_features import choose_columns
df = choose_columns(df, best_correlation_column)

df
# Out:
#       OverallQual  GrLivArea  GarageCars  ExterQual  GarageArea  TotalBsmtSF  \
# 0               7       1710           2        2.0         548          856
# 1               6       1262           2        3.0         460         1262
# 2               7       1786           2        2.0         608          920
# 3               7       1717           3        3.0         642          756
# 4               8       2198           3        2.0         836         1145
# ...           ...        ...         ...        ...         ...          ...
# 1455            6       1647           2        3.0         460          953
# 1456            6       2073           2        3.0         500         1542
# 1457            7       2340           1        0.0         252         1152
# 1458            5       1078           1        3.0         240         1078
# 1459            5       1256           1        2.0         276         1256
#
#       1stFlrSF  BsmtQual  KitchenQual  FullBath  TotRmsAbvGrd  YearBuilt  \
# 0          856       2.0          2.0         2             8       2003
# 1         1262       2.0          3.0         2             6       1976
# 2          920       2.0          2.0         2             6       2001
# 3          961       4.0          2.0         1             7       1915
# 4         1145       2.0          2.0         2             9       2000
# ...        ...       ...          ...       ...           ...        ...
# 1455       953       2.0          3.0         2             7       1999
# 1456      2073       2.0          3.0         2             7       1978
# 1457      1188       4.0          2.0         2             9       1941
# 1458      1078       4.0          2.0         1             5       1950
# 1459      1256       4.0          3.0         1             6       1965
#
#       YearRemodAdd
# 0             2003
# 1             1976
# 2             2002
# 3             1970
# 4             2000
# ...            ...
# 1455          2000
# 1456          1988
# 1457          2006
# 1458          1996
# 1459          1965
#
# [1460 rows x 13 columns]
