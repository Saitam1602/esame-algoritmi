# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder

df = pd.read_csv("../data/processed/out.csv")
df.head(1)
# Out:
#    Unnamed: 0  Id  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 0           0   1          60       RL         65.0     8450   Pave
#
#              Alley LotShape LandContour  ... PoolArea   PoolQC     Fence  \
# 0  No alley access      Reg         Lvl  ...        0  No pool  No fence
#
#   MiscFeature MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# 0        none       0      2   2008       WD         Normal     208500
#
# [1 rows x 82 columns]

# %%
X_columns = ['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF',
       'FullBath', 'YearBuilt', '1stFlrSF', 'YearRemodAdd', 'GarageYrBlt',
       'TotRmsAbvGrd']

y_columns = ["SalePrice"]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(random_state=42)

param_grid = {'max_depth': [None] + [x for x in range(0, 20, 5)], "min_samples_leaf": [
    None] + [x for x in range(0, 20, 5)], "min_samples_split": [None] + [x for x in range(0, 20, 5)]}


grid_search = GridSearchCV(model, param_grid=param_grid, verbose=0, cv=5)
grid_search.fit(df[X_columns], df[y_columns])

grid_search.best_params_

best_params = {'max_depth': 8, 'min_samples_leaf': 2,'min_samples_split': 8}

# max_depth: 8 {'min_samples_leaf': 2} {'min_samples_split': 8}
# Out:
# c:\Users\MatiasMaiorano\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\Users\MatiasMaiorano\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# c:\Users\MatiasMaiorano\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
best_params = {'max_depth': 8, 'min_samples_leaf': 2,'min_samples_split': 8}

model = RandomForestRegressor(random_state=42, **best_params)

model.fit(df[X_columns], df[y_columns])
# Out:
# <ipython-input-26-2dfa802d757f>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(df[X_columns], df[y_columns])
# RandomForestRegressor(max_depth=8, min_samples_leaf=2, min_samples_split=8,
#                       random_state=42)

# %%
oe = OrdinalEncoder()

df_test = pd.read_csv("../data/raw/test.csv")

categorical_columns = df_test.select_dtypes(include=['object']).columns.tolist()

for c in categorical_columns:
    df_test[[c]] = oe.fit_transform(df_test[[c]])

# %%
predictions = model.predict(df_test[X_columns])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-2e89b9c0625c> in <module>
# ----> 1 predictions = model.predict(df_test[X_columns])
#
# c:\Users\MatiasMaiorano\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     989         check_is_fitted(self)
#     990         # Check data
# --> 991         X = self._validate_X_predict(X)
#     992
#     993         # Assign chunk of trees to jobs
#
# c:\Users\MatiasMaiorano\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _validate_X_predict(self, X)
#     603         Validate X whenever one tries to predict, apply, predict_proba."""
#     604         check_is_fitted(self)
# --> 605         X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     606         if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
# ...
