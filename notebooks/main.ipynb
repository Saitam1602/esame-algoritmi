# %%
import pandas as pd

path = "../data/raw/train.csv"

# %%
from functions.data import make_dataset

df = make_dataset.load_data(path)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street            Alley  \
# 0   1          60       RL         65.0     8450   Pave  No alley access
# 1   2          20       RL         80.0     9600   Pave  No alley access
# 2   3          60       RL         68.0    11250   Pave  No alley access
# 3   4          70       RL         60.0     9550   Pave  No alley access
# 4   5          60       RL         84.0    14260   Pave  No alley access
#
#   LotShape LandContour Utilities  ... PoolArea   PoolQC     Fence MiscFeature  \
# 0      Reg         Lvl    AllPub  ...        0  No pool  No fence        none
# 1      Reg         Lvl    AllPub  ...        0  No pool  No fence        none
# 2      IR1         Lvl    AllPub  ...        0  No pool  No fence        none
# 3      IR1         Lvl    AllPub  ...        0  No pool  No fence        none
# 4      IR1         Lvl    AllPub  ...        0  No pool  No fence        none
#
# ...

# %%
from functions.features import build_features

df = build_features.encode_categorical_data(df)
df.head()
# Out:
#       MSZoning
# 0          3.0
# 1          3.0
# 2          3.0
# 3          3.0
# 4          3.0
# ...        ...
# 1455       3.0
# 1456       3.0
# 1457       3.0
# 1458       3.0
# 1459       3.0
#
# [1460 rows x 1 columns]
#       Street
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# ...      ...
# 1455     1.0
# 1456     1.0
# 1457     1.0
# 1458     1.0
# 1459     1.0
#
# [1460 rows x 1 columns]
#       Alley
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# ...     ...
# 1455    1.0
# 1456    1.0
# 1457    1.0
# 1458    1.0
# 1459    1.0
#
# [1460 rows x 1 columns]
#       LotShape
# 0          3.0
# 1          3.0
# 2          0.0
# 3          0.0
# 4          0.0
# ...        ...
# 1455       3.0
# 1456       3.0
# 1457       3.0
# 1458       3.0
# 1459       3.0
#
# [1460 rows x 1 columns]
#       LandContour
# 0             3.0
# 1             3.0
# 2             3.0
# 3             3.0
# 4             3.0
# ...
